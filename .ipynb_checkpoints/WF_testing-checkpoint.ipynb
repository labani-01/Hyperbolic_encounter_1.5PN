# %%
import warnings
warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
import lal
import pycbc
from pycbc import conversions, psd, filter, noise, types
from pycbc.waveform import get_fd_waveform, get_td_waveform
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Generate TD and FD waveform

# %%
dt = 1.0/2048
df = 1.0/8
length = int(1/df/dt)
f_lower = 15.0

mass1 = 60
mass2 = 60
distance = 80
ecc = 3.14

# %%
hp_td, hc_td = get_td_waveform(approximant="Hyperbolic15PNhphc",
                         mass1 = 549.2691306990909, mass2 = 11.73982755883141, f_lower=20, 
                         delta_t=0.00048828125, delta_f=df, phi0=1.3336968688551911, vmax=0.23632596451557863, duration=int(1/df),
                         spin1_a=0.9416897599379191, spin1_polar=2.335714092603503, spin1_azimuthal=5.413816165792178, spin2_a=0.23844929495648023, spin2_polar=1.0587983708383981, spin2_azimuthal=0.8739432467818489, distance=1.0, inclination=0.0, eccentricity=1.339691074547431)

plt.plot(hp_td.sample_times, hp_td)
plt.xlabel('Time')
plt.show()
# Out:
# /home/labani-roy/hyper_pycbc_waveform/hyperbolic_waveform_generate.py:49: RuntimeWarning: invalid value encountered in sqrt
#   kz0 = np.sqrt(1-kx0**2-ky0**2)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hp_td, hc_td = get_td_waveform(approximant="Hyperbolic15PNhphc",
#       2                          mass1 = 549.2691306990909, mass2 = 11.73982755883141, f_lower=20,
#       3                          delta_t=0.00048828125, delta_f=df, phi0=1.3336968688551911, vmax=0.23632596451557863, duration=int(1/df),
#       4                          spin1_a=0.9416897599379191, spin1_polar=2.335714092603503, spin1_azimuthal=5.413816165792178, spin2_a=0.23844929495648023, spin2_polar=1.0587983708383981, spin2_azimuthal=0.8739432467818489, distance=1.0, inclination=0.0, eccentricity=1.339691074547431)
#       6 plt.plot(hp_td.sample_times, hp_td)
#       7 plt.xlabel('Time')
#
# File ~/anaconda3/envs/hyperbolic/lib/python3.11/site-packages/pycbc/waveform/waveform.py:599, in get_td_waveform(template, **kwargs)
#     597     required = parameters.td_required
#     598 check_args(input_params, required)
# --> 599 return wav_gen(**input_params)
#
# File ~/hyper_pycbc_waveform/Hyperbolic15PNhphc.py:27, in hyperbolic_waveform_td(phi0, vmax, duration, **kwds)
#      24 theta2i = kwds['spin2_polar']
#      25 delta_t = kwds['delta_t']
# ---> 27 hp, hc = hyperbolic_waveform_generate.hphc_15PN(phi0, vmax, duration, chi1, theta1i, phi1i, chi2, theta2i, phi2i, m1, m2, et0, R, Theta, delta_t)
#      29 hp = TimeSeries(hp, delta_t)
#      30 hc = TimeSeries(hc, delta_t)
#
# File ~/hyper_pycbc_waveform/hyperbolic_waveform_generate.py:136, in hphc_15PN(phi0, vmax, duration, chi1, theta1i, phi1i, chi2, theta2i, phi2i, m1, m2, et0, R, Theta, delta_t)
#     133 y0 = np.array([xi0,et0,phi0,k0[0],k0[1],k0[2],s10[0],s10[1],s10[2],s20[0],s20[1],s20[2]])
#     135 #solve differential equation
# --> 136 sol = solve_ivp(dy,tspan,y0, method = 'RK45',t_eval = t_eval, rtol = 0.5*(10**(-12)))
#     138 #unpack solution
#     139 xi = sol.y[0]
#
# File ~/anaconda3/envs/hyperbolic/lib/python3.11/site-packages/scipy/integrate/_ivp/ivp.py:621, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     618 if method in METHODS:
#     619     method = METHODS[method]
# --> 621 solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
#     623 if t_eval is None:
#     624     ts = [t0]
#
# File ~/anaconda3/envs/hyperbolic/lib/python3.11/site-packages/scipy/integrate/_ivp/rk.py:89, in RungeKutta.__init__(self, fun, t0, y0, t_bound, max_step, rtol, atol, vectorized, first_step, **extraneous)
#      85 def __init__(self, fun, t0, y0, t_bound, max_step=np.inf,
#      86              rtol=1e-3, atol=1e-6, vectorized=False,
#      87              first_step=None, **extraneous):
#      88     warn_extraneous(extraneous)
# ---> 89     super().__init__(fun, t0, y0, t_bound, vectorized,
#      90                      support_complex=True)
#      91     self.y_old = None
#      92     self.max_step = validate_max_step(max_step)
#
# File ~/anaconda3/envs/hyperbolic/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:135, in OdeSolver.__init__(self, fun, t0, y0, t_bound, vectorized, support_complex)
#     133 self.t_old = None
#     134 self.t = t0
# --> 135 self._fun, self.y = check_arguments(fun, y0, support_complex)
#     136 self.t_bound = t_bound
#     137 self.vectorized = vectorized
#
# File ~/anaconda3/envs/hyperbolic/lib/python3.11/site-packages/scipy/integrate/_ivp/base.py:20, in check_arguments(fun, y0, support_complex)
#      17     raise ValueError("`y0` must be 1-dimensional.")
#      19 if not np.isfinite(y0).all():
# ---> 20     raise ValueError("All components of the initial state `y0` must be finite.")
#      22 def fun_wrapped(t, y):
#      23     return np.asarray(fun(t, y), dtype=dtype)
#
# ValueError: All components of the initial state `y0` must be finite.

# %%
PSD = psd.analytical.aLIGO175MpcT1800545(int(length/2+1), df, low_freq_cutoff=f_lower)

hp_fd, hc_fd = get_fd_waveform(approximant="Hyperbolic15PNhphc",
                         mass1 = mass1, mass2 = mass2, f_lower=f_lower,
                         delta_t=dt, delta_f=df, Phi0=0.3, xi0=0.0005, vmax=0.5, duration=int(1/df),
                         spin1_a=1, spin1_polar=0.5, spin1_azimuthal=0.35, spin2_a=1, spin2_polar=0.8, spin2_azimuthal=1, distance=distance, inclination=2, eccentricity=1.5)

plt.loglog(hp_fd.sample_frequencies, hp_fd)
plt.xlabel('Frequency')
plt.xlim([15,400])
plt.loglog(PSD.sample_frequencies, np.sqrt(PSD), label='175 MPc aLIGO')
plt.legend()
# Out:
# /Users/rahul/.pyenv/versions/mygpu/lib/python3.10/site-packages/matplotlib/cbook.py:1762: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/rahul/.pyenv/versions/mygpu/lib/python3.10/site-packages/matplotlib/cbook.py:1398: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
nt = noise.gaussian.noise_from_psd(len(hp_td), dt, PSD)
nt = types.timeseries.TimeSeries(nt, dt, epoch=hp_td.start_time)

data = nt + hp_td

snr = np.abs(filter.matched_filter(hp_fd, data, PSD, low_frequency_cutoff=15))[0]
print('SNR: ', snr)
# Out:
# SNR:  10.16339786804274

# %% [markdown]
# ### Whitening

# %%
nt = noise.gaussian.noise_from_psd(len(hp_td), dt, PSD)
nt = types.timeseries.TimeSeries(nt, dt, epoch=-4.008789062)

data = nt + hp_td

nt_fd = nt.to_frequencyseries()
data_whiten = data.whiten(2,4)

#plt.loglog(nt_fd.sample_frequencies, nt_fd)
#plt.plot(PSD.sample_frequencies, PSD)

plt.plot(data_whiten.sample_times, data_whiten)
